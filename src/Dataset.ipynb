# %%
import os
from pathlib import Path
from random import randint
from typing import List

import matplotlib.pyplot as plt
import cv2
from albumentations import (
    Compose,
    HorizontalFlip,
    Normalize,
    Resize,
    SmallestMaxSize,
    CenterCrop
)

from albumentations.pytorch import ToTensorV2
from torch import Tensor
from torch.utils.data import Dataset, DataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e9b0a1a5ebc6> in <module>
#       6 import matplotlib.pyplot as plt
#       7 import cv2
# ----> 8 from albumentations import (
#       9     Compose,
#      10     HorizontalFlip,
#
# ModuleNotFoundError: No module named 'albumentations'

# %%
from Dataset import LandscapesDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-38af8f43adf8> in <module>
# ----> 1 from Dataset import LandscapesDataset
#
# ~/DaytimeTranslation/src/Dataset.py in <module>
#       5 import matplotlib.pyplot as plt
#       6 import cv2
# ----> 7 from albumentations import (
#       8     Compose,
#       9     HorizontalFlip,
#
# ModuleNotFoundError: No module named 'albumentations'

# %%
path = Path('/home/jupyter/work/resources/DaytimeTranslation/data/images')

dataset = LandscapesDataset(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2fea70342737> in <module>
#       1 path = Path('/home/jupyter/work/resources/DaytimeTranslation/data/images')
#       2
# ----> 3 dataset = LandscapesDataset(path)
#
# NameError: name 'LandscapesDataset' is not defined

# %%
len(dataset.filenames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b5e5ded9a4c6> in <module>
# ----> 1 len(dataset.filenames)
#
# NameError: name 'dataset' is not defined

# %%
image = cv2.imread('/home/jupyter/work/resources/DaytimeTranslation/data/images/8c005f73-d2f9-4841-acc7-5bdc9d73bd9d/00055.jpg')
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1899a5cf3200> in <module>
#       1 image = cv2.imread('/home/jupyter/work/resources/DaytimeTranslation/data/images/8c005f73-d2f9-4841-acc7-5bdc9d73bd9d/00055.jpg')
# ----> 2 plt.imshow(image)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
train_dataloader = DataLoader(
            dataset=dataset,
            batch_size=4,
            num_workers=4,
        )

# %%
a, b = next(iter(train_dataloader))

# %%
plt.imshow((b[0].permute(1,2,0) * Tensor([0.406, 0.456, 0.485]) + 
            Tensor([0.225, 0.224, 0.229])))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
